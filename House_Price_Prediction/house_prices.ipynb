# %% [markdown]
# # Предсказание стоимости жилья с помощью продвинутых методов регрессии. Задание House Prices с Kaggle

# %% [markdown]
# ## Обзор задачи, входных данных

# %% [markdown]
# В этом проекте перед нами стоит реальная задача предсказания стоимости домов, учитывая 79 признаков, описывающих почти каждый аспект жилого дома.

# %% [markdown]
# Критериями оценки этого конкурса на Kaggle является _RMSLE_ - среднеквадратичная ошибка между логарифмом прогнозируемого значения и логарифмом наблюдаемой цены продажи.

# %% [markdown]
# ## Шаг 1. Выгрузка и исследование данных

# %% [markdown]
# Для начала мы импортируем необходимые библиотеки и наборы данных:

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 90)

from sklearn.neighbors import KNeighborsRegressor
import scipy.stats

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from pycaret.regression import setup, compare_models


from catboost import  CatBoostRegressor
from sklearn.linear_model import BayesianRidge, HuberRegressor, Ridge, OrthogonalMatchingPursuit
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRFRegressor

from sklearn.model_selection import KFold, cross_val_score

import optuna

from sklearn.preprocessing import StandardScaler, OneHotEncoder #Стандартизация данных и кодирование категориальных величин
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline #Объединение нескольких этапов обработки данных в один последовательный процесс
from sklearn.impute import SimpleImputer #Замена недостающих данных, используя описательную статистику
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Выгрузка датасетов
train0 = pd.read_csv('train.csv')
test0 = pd.read_csv('test.csv')
sample_submission = pd.read_csv('sample_submission.csv')

# %%
train0
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test0
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %% [markdown]
# На этом шаге уже хочется создать какой-то план действий внутри проекта

# %% [markdown]
# <ul> <strong> План: </strong>
# <li>Чистка данных</li>
# <li>Отсев признаков</li>
# <li>Преобразование признаков</li>
# <li>Кодирование</li>
# <li>Масштабирование</li>
# <li>Преобразование значений</li>
# <li>Выбор модели</li>
# <li>Оптимизация гиперпараметров</li>
# <li>Составление ансамбля</li>
# </ul>

# %% [markdown]
# Начнем работу с очистки данных

# %% [markdown]
# ## Шаг 2. Чистка данных

# %%
sample_submission
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %% [markdown]
# Оценим общее количество пропущенных значений в каждом столбце:

# %%
train0.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
test0.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType        894
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# В тренировочном и тестовом наборах данных присутствуют пропущенные значения. Объединим данные, чтобы заполнить недостающие данные, а потом снова их разделим

# %%
target = train0['SalePrice']
test_ids = test0['Id']

train1 = train0.drop(['Id', 'SalePrice'], axis=1)
test1 = test0.drop('Id', axis=1)

data1 = pd.concat([train1, test1], axis=0).reset_index(drop=True)
data1
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2914         160       RM         21.0     1936   Pave   NaN      Reg
# 2915         160       RM         21.0     1894   Pave   NaN      Reg
# 2916          20       RL        160.0    20000   Pave   NaN      Reg
# 2917          85       RL         62.0    10441   Pave   NaN      Reg
# 2918          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
target
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
data2 = data1.copy()

# %% [markdown]
# Далее выберем данные с правильными типами. Нас интересуют числовые значения

# %%
data2['MSSubClass'] = data2['MSSubClass'].astype(str)

# %% [markdown]
# Просмотрев данные, я пришел к выводу что MSSubClass - единственный столбец, который был закодирован. Так что мы можем переходить к следующему пункту

# %% [markdown]
# ### Заполнение пропущенных категориальных значений

# %% [markdown]
# Проанализируем входные данные (столбцы с категориальными величинами), разобьем их на 2 типа - где NaN несет какой-либо смысл для нашей задачи и где нет. В зависимости от этого перезаполним таблицу

# %%
# Impute using a constant value
for column in [
    'Alley',
    'BsmtQual',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'BsmtFinType2',
    'FireplaceQu',
    'GarageType',
    'GarageFinish',
    'GarageQual',
    'GarageCond',
    'PoolQC',
    'Fence',
    'MiscFeature'
]:
    data2[column] = data2[column].fillna("None")
    
# Impute using the column mode
for column in [
    'MSZoning',
    'Utilities',
    'Exterior1st',
    'Exterior2nd',
    'MasVnrType',
    'Electrical',
    'KitchenQual',
    'Functional',
    'SaleType'
]:
    data2[column] = data2[column].fillna(data2[column].mode()[0])

# %%
data3 = data2.copy()

# %% [markdown]
# ### Заполнение пропущенных числовых значений

# %% [markdown]
# Воcпользуемся kNN регрессией для заполнения отсутвующих числовых значений. Но перед этим создадим функцию заполнения какого-то столбца

# %%
def knn_impute(df, na_target):
    df = df.copy()
    
    numeric_df = df.select_dtypes(np.number)
    non_na_columns = numeric_df.loc[:, numeric_df.isna().sum() == 0].columns
    
    y_train = numeric_df.loc[numeric_df[na_target].isna() == False, na_target]
    X_train = numeric_df.loc[numeric_df[na_target].isna() == False, non_na_columns]
    X_test = numeric_df.loc[numeric_df[na_target].isna() == True, non_na_columns]
    
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    
    y_pred = knn.predict(X_test)
    
    df.loc[df[na_target].isna() == True, na_target] = y_pred
    
    return df

# %% [markdown]
# Проанализируем, какие столбцы нам нужно заполнить. Сделаем это с помощью функции, написанной выше

# %%
data3.columns[data3.isna().sum() > 0]
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %%
for column in [
    'LotFrontage', 
    'MasVnrArea', 
    'BsmtFinSF1', 
    'BsmtFinSF2', 
    'BsmtUnfSF',
    'TotalBsmtSF', 
    'BsmtFullBath', 
    'BsmtHalfBath', 
    'GarageYrBlt',
    'GarageCars', 
    'GarageArea'
]:
    data3 = knn_impute(data3, column)

# %%
data4 = data3.copy()

# %% [markdown]
# На этом мы закончили очистку данных

# %% [markdown]
# ## Разработка функций

# %%
data4["SqFtPerRoom"] = data4["GrLivArea"] / (data4["TotRmsAbvGrd"] +
                                                       data4["FullBath"] +
                                                       data4["HalfBath"] +
                                                       data4["KitchenAbvGr"])           #средняя площадь комнаты

data4['Total_Home_Quality'] = data4['OverallQual'] + data4['OverallCond']               #общее качество дома

data4['Total_Bathrooms'] = (data4['FullBath'] + (0.5 * data4['HalfBath']) +
                               data4['BsmtFullBath'] + (0.5 * data4['BsmtHalfBath']))   #общее количество ванных комнат

data4["HighQualSF"] = data4["1stFlrSF"] + data4["2ndFlrSF"]       #общая площадь

# %%
data5 = data4.copy()

# %% [markdown]
# ## Шаг 3. Преобразование признаков

# %%
data5
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            60       RL         65.0     8450   Pave  None      Reg
# 1            20       RL         80.0     9600   Pave  None      Reg
# 2            60       RL         68.0    11250   Pave  None      IR1
# 3            70       RL         60.0     9550   Pave  None      IR1
# 4            60       RL         84.0    14260   Pave  None      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 2914        160       RM         21.0     1936   Pave  None      Reg
# 2915        160       RM         21.0     1894   Pave  None      Reg
# 2916         20       RL        160.0    20000   Pave  None      Reg
# 2917         85       RL         62.0    10441   Pave  None      Reg
# 2918         60       RL         74.0     9627   Pave  None      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %% [markdown]
# Исследуем наши данные на предмет дисбалансности. Вычислим ассиметрию какого-то из столбцов. Например LotFrontage

# %%
scipy.stats.skew(data5['LotFrontage'])
# Out:
# 1.3407511399227516

# %% [markdown]
# Как мы видим, имеется ассиметрия вправо. Вычислим ассиметрию для каждого из числовых столбцов и обратим это во фрейм данных

# %%
skew_df = pd.DataFrame(data5.select_dtypes(np.number).columns, columns=['Feature'])
skew_df['Skew'] = skew_df['Feature'].apply(lambda feature: scipy.stats.skew(data5[feature]))
skew_df['Absolute Skew'] = skew_df['Skew'].apply(abs)
skew_df['Skewed'] = skew_df['Absolute Skew'].apply(lambda x: True if x >= 0.5 else False) #помечаем столбцы с ассиметрией >= 0.5
skew_df
# Out:
#                Feature       Skew  Absolute Skew  Skewed
# 0          LotFrontage   1.340751       1.340751    True
# 1              LotArea  12.822431      12.822431    True
# 2          OverallQual   0.197110       0.197110   False
# 3          OverallCond   0.570312       0.570312    True
# 4            YearBuilt  -0.599806       0.599806    True
# 5         YearRemodAdd  -0.451020       0.451020   False
# 6           MasVnrArea   2.603682       2.603682    True
# 7           BsmtFinSF1   1.425516       1.425516    True
# 8           BsmtFinSF2   4.146111       4.146111    True
# 9            BsmtUnfSF   0.919322       0.919322    True
# 10         TotalBsmtSF   1.162806       1.162806    True
# 11            1stFlrSF   1.469604       1.469604    True
# 12            2ndFlrSF   0.861675       0.861675    True
# 13        LowQualFinSF  12.088761      12.088761    True
# 14           GrLivArea   1.269358       1.269358    True
# ...

# %%
data5[skew_df.query("Skewed == True")['Feature'].values].describe()
# Out:
#        LotFrontage        LotArea  OverallCond    YearBuilt   MasVnrArea  \
# count  2919.000000    2919.000000  2919.000000  2919.000000  2919.000000
# mean     70.154916   10168.114080     5.564577  1971.312778   102.189654
# std      22.697641    7886.996359     1.113131    30.291442   178.934095
# min      21.000000    1300.000000     1.000000  1872.000000     0.000000
# 25%      60.000000    7478.000000     5.000000  1953.500000     0.000000
# 50%      70.000000    9453.000000     5.000000  1973.000000     0.000000
# 75%      80.100000   11570.000000     6.000000  2001.000000   164.000000
# max     313.000000  215245.000000     9.000000  2010.000000  1600.000000
#
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF  \
# count  2919.000000  2919.000000  2919.000000  2919.000000  2919.000000
# mean    441.332580    49.576841   560.797670  1051.679822  1159.581706
# std     455.559081   169.176867   439.470508   440.722380   392.362079
# ...

# %% [markdown]
# Выше мы запросили описание данных из ассиметричных столбцов. Как видим, у многиъ из них минимальное значение равно нулю. Отрицательных данных нет, так как данные из реального мира. Но нам нужно прологарифмировать данные, чтобы избавится от ассиметрии, что для стандартной функции логарифма невозможно при нудевых данных. Воспользуемся функцией `log1p` из `NumPy`

# %%
for column in skew_df.query("Skewed == True")['Feature'].values:
    data5[column] = np.log1p(data5[column])

# %% [markdown]
# Проверим, как поменялась асимметрия:

# %%
skew_df = pd.DataFrame(data5.select_dtypes(np.number).columns, columns=['Feature'])
skew_df['Skew'] = skew_df['Feature'].apply(lambda feature: scipy.stats.skew(data5[feature]))
skew_df['Absolute Skew'] = skew_df['Skew'].apply(abs)
skew_df['Skewed'] = skew_df['Absolute Skew'].apply(lambda x: True if x >= 0.5 else False) #помечаем столбцы с ассиметрией >= 0.5
skew_df
# Out:
#                Feature       Skew  Absolute Skew  Skewed
# 0          LotFrontage  -0.929468       0.929468    True
# 1              LotArea  -0.504751       0.504751    True
# 2          OverallQual   0.197110       0.197110   False
# 3          OverallCond  -0.746183       0.746183    True
# 4            YearBuilt  -0.626215       0.626215    True
# 5         YearRemodAdd  -0.451020       0.451020   False
# 6           MasVnrArea   0.511138       0.511138    True
# 7           BsmtFinSF1  -0.618036       0.618036    True
# 8           BsmtFinSF2   2.458996       2.458996    True
# 9            BsmtUnfSF  -2.159204       2.159204    True
# 10         TotalBsmtSF  -4.981542       4.981542    True
# 11            1stFlrSF   0.064828       0.064828   False
# 12            2ndFlrSF   0.305049       0.305049   False
# 13        LowQualFinSF   8.557690       8.557690    True
# 14           GrLivArea   0.013188       0.013188   False
# ...

# %% [markdown]
# Стало лучше. Но тут мы можем обратить внимание, что есть признаки, такие как `MoSold`. Посмотрим, что представляют из себя эти данные:

# %%
data5['MoSold'].unique()
# Out:
# array([ 2,  5,  9, 12, 10,  8, 11,  4,  1,  7,  3,  6], dtype=int64)

# %% [markdown]
# Эти данные представляют из себя номера месяцев, но пока наша модель будет воспринимать их как числа, не смотря на то, что на самом деле `1` и `12`, к примеру, очень близки по сути друг к другу, так как обозначают холодное время года. Давайте применим к подобным признаком `косинусоидальное преобразование`, чтобы обратить "реальный" смысл признака в "численный"

# %% [markdown]
# Рассмотрим функцию $y = -\cos(0.5236 \cdot x)$ - в точках с $x = 0$ и $x = 12$, она принимает равные значения $y = -1$. Знак `-` показывает, что месяцы холодные.

# %%
data5['MoSold'] = -np.cos(0.5236 * data5['MoSold'])

# %%
data6 = data5.copy()

# %% [markdown]
# ## Шаг 4. Кодирование категориальных величин

# %% [markdown]
# Так как мы уже позаботились о приведении величин к нужной нам форме, закодировать их не проблема

# %%
data6 = pd.get_dummies(data6)

# %%
data7 = data6.copy()

# %% [markdown]
# ## Шаг 5. Стандартизация данных, масштабирование

# %% [markdown]
# Проведем стандартизацию с помощью `StandartScaler` из `sk-learn`

# %%
scaler = StandardScaler()
scaler.fit(data7)

data7 = pd.DataFrame(scaler.transform(data7), index=data7.index, columns=data7.columns)

data8 = data7.copy()

# %% [markdown]
# ## Шаг 6. Изменение целевых данных

# %%
plt.figure(figsize=(20, 8))

plt.subplot(1, 2, 1)
sns.distplot(target, kde=True, fit=scipy.stats.norm)
plt.title('Without Log Transform')


plt.subplot(1, 2, 2)
sns.distplot(np.log(target), kde=True, fit=scipy.stats.norm) #минимум выше нуля
plt.title('With Log Transform')
plt.xlabel('Log SalePrice')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Как видно из графиков, прологорифмированные данные гораздо лучше описывают нормальное распределение. Осуществим преобразование:

# %%
log_target = np.log(target)
log_target
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
#           ...
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: SalePrice, Length: 1460, dtype: float64

# %% [markdown]
# ### Обратное разделение данных

# %% [markdown]
# До этого мы объединяли тестовые и тренировочные данные удобства обработки. Разделим их обратно для тренировки моделей

# %%
train_final = data8.loc[:train0.index.max(), :].copy()
test_final = data8.loc[train0.index.max() + 1:, :].reset_index(drop=True).copy()

# %%
train_final
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       -0.064176 -0.103719     0.646183    -0.435439   1.040634
# 1        0.536077  0.146544    -0.063185     1.906370   0.161526
# 2        0.066112  0.457629     0.646183    -0.435439   0.975922
# 3       -0.295084  0.136301     0.646183    -0.435439  -1.869638
# 4        0.677357  0.922662     1.355551    -0.435439   0.943542
# ...           ...       ...          ...          ...        ...
# 1455    -0.200527 -0.231508    -0.063185    -0.435439   0.911146
# 1456     0.711638  0.767440    -0.063185     0.454875   0.227056
# 1457    -0.020100  0.029092     0.646183     2.514892  -0.996100
# 1458     0.066112  0.170303    -0.772552     0.454875  -0.696444
# 1459     0.349325  0.214215    -0.772552     0.454875  -0.200076
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         0.896833    1.210174    0.783229   -0.363076  -0.326949
# ...

# %%
test_final
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        0.536077  0.521437    -0.772552     0.454875  -0.332070
# 1        0.572040  0.923625    -0.063185     0.454875  -0.431241
# 2        0.310504  0.862607    -0.772552    -0.435439   0.846305
# 3        0.462798  0.222291    -0.063185     0.454875   0.878733
# 4       -1.252596 -1.130892     1.355551    -0.435439   0.683917
# ...           ...       ...          ...          ...        ...
# 1454    -3.284214 -2.993401    -1.481920     1.226101  -0.035461
# 1455    -3.284214 -3.036401    -1.481920    -0.435439  -0.035461
# 1456     2.549545  1.586172    -0.772552     1.226101  -0.365110
# 1457    -0.200527  0.311255    -0.772552    -0.435439   0.683917
# 1458     0.310504  0.152052     0.646183    -0.435439   0.716427
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0        -1.113625   -0.804554    0.645518    2.285649  -0.013563
# ...

# %% [markdown]
# ##  Шаг 7. Выбор модели

# %% [markdown]
# В помощью библиотеки `PyCaret` оценим, какие модели будут более эффективно вести себя с нашим набором данных

# %%
#_ = setup(data=pd.concat([train_final, log_target], axis=1), target='SalePrice')

# %%
#compare_models()

# %% [markdown]
# Вообще говоря, мне нравится идея построить модель на основе `catboost`. Он отлично показывает себя на нашем наборе данных

# %% [markdown]
# ## Шаг 8. Базовая модель

# %% [markdown]
# Обучим нашу модель:

# %%
baseline_model = CatBoostRegressor(verbose=0)

# %%
baseline_model.fit(train_final, log_target)

# %% [markdown]
# ## Шаг 9. Оптимизация гиперпараметров

# %% [markdown]
# Для оптимизации гиперпараметров будем использовать библиотеку `Optuna` и оптимизацию случайным образом

# %%
''' def gbr_objective(trial):
    n_estimators     = trial.suggest_int('n_estimators', 50, 600)
    max_depth       = trial.suggest_int('max_depth', 1, 5)
    min_samples_split    = trial.suggest_int('min_samples_split', 2, 4)
    learning_rate     = trial.suggest_loguniform('learning_rate', 1e-3, 0.1)
    
    model = GradientBoostingRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        learning_rate=learning_rate
    )
    
    model.fit(train_final, log_target)
    
    cv_score = np.exp(np.sqrt(-cross_val_score(model, train_final, log_target, scoring='neg_mean_squared_error', cv=kf)))
    
    return np.mean(cv_score) '''
# Out:
# " def gbr_objective(trial):\n    n_estimators     = trial.suggest_int('n_estimators', 50, 600)\n    max_depth       = trial.suggest_int('max_depth', 1, 5)\n    min_samples_split    = trial.suggest_int('min_samples_split', 2, 4)\n    learning_rate     = trial.suggest_loguniform('learning_rate', 1e-3, 0.1)\n    \n    model = GradientBoostingRegressor(\n        n_estimators=n_estimators,\n        max_depth=max_depth,\n        min_samples_split=min_samples_split,\n        learning_rate=learning_rate\n    )\n    \n    model.fit(train_final, log_target)\n    \n    cv_score = np.exp(np.sqrt(-cross_val_score(model, train_final, log_target, scoring='neg_mean_squared_error', cv=kf)))\n    \n    return np.mean(cv_score) "

# %%
''' study = optuna.create_study(direction='minimize')
study.optimize(gbr_objective, n_trials=100) '''
# Out:
# " study = optuna.create_study(direction='minimize')\nstudy.optimize(gbr_objective, n_trials=100) "

# %% [markdown]
# ## Шаг 10. Создание ансамбля

# %%
catboost_params = {
    'iterations': 6000,
    'learning_rate': 0.005,
    'depth': 4,
    'l2_leaf_reg': 1,
    'eval_metric':'RMSE',
    'early_stopping_rounds': 200,
    'random_seed': 42
}

br_params = {
    'n_iter': 304,
    'tol': 0.16864712769300896,
    'alpha_1': 5.589616542154059e-07,
    'alpha_2': 9.799343618469923,
    'lambda_1': 1.7735725582463822,
    'lambda_2': 3.616928181181732e-06
}

gbr_params = {
    'n_estimators': 600,
    'max_depth': 4,
    'min_samples_split': 5,
    'learning_rate': 0.01
}

ridge_params = {
    'alpha': 631.1412445239156
}

# %% [markdown]
# Создадим словарь, сопоставляющий название модели с реальным названием. Из decision tree моделей оставим только catboost, так как он показывает лучшие результаты (в последствии поменяли huber на gbr). Обучим также различные линейные модели:

# %%
models = {
    "catboost": CatBoostRegressor(**catboost_params,verbose=0),
    "br": BayesianRidge(**br_params),
    #"huber": HuberRegressor(),
    "gbr": GradientBoostingRegressor(**gbr_params),
    "ridge": Ridge(**ridge_params),
    "omp": OrthogonalMatchingPursuit()
}

# %%
for name, model in models.items():
    model.fit(train_final, log_target)
    print(name + " trained.")
# Out:
# catboost trained.
# br trained.
# gbr trained.
# ridge trained.
# omp trained.

# %% [markdown]
# ## Шаг 11. Cравнение

# %% [markdown]
# Выполним процедуру перекрестной проверки с 10-ю фолдами

# %%
''' results = {}

kf = KFold(n_splits=10)
for name, model in models.items():
    result = np.exp(np.sqrt(-cross_val_score(model, train_final, log_target, scoring='neg_mean_squared_error', cv=kf)))
    results[name] = result '''
# Out:
# " results = {}\n\nkf = KFold(n_splits=10)\nfor name, model in models.items():\n    result = np.exp(np.sqrt(-cross_val_score(model, train_final, log_target, scoring='neg_mean_squared_error', cv=kf)))\n    results[name] = result "

# %%
''' results '''
# Out:
# ' results '

# %% [markdown]
# Посчитаем среднеквадратичное отклонение по всем фолдам для кажой из моделей:

# %%
''' for name, result in results.items():
    print('\n-------------\n' + name + '\n-------------\n')
    print(np.mean(result))
    print(np.std(result)) '''
# Out:
# " for name, result in results.items():\n    print('\n-------------\n' + name + '\n-------------\n')\n    print(np.mean(result))\n    print(np.std(result)) "

# %% [markdown]
# Как видим, у Huber regression очень высокая среднеквадратичная ошибка, как и стандартное отклонение. Откажемся от него в пользу gbr

# %%
''' target.describe() '''
# Out:
# ' target.describe() '

# %% [markdown]
# Ошибка очень мала по сравнению с нашими данными, это прекрасно

# %%
''' plt.figure(figsize=(16, 10))

for name, model in models.items():    
    sns.displot(results[name], bins=10, kde=True)
    
plt.title("CV Error Distibutions")
plt.show() '''
# Out:
# ' plt.figure(figsize=(16, 10))\n\nfor name, model in models.items():    \n    sns.displot(results[name], bins=10, kde=True)\n    \nplt.title("CV Error Distibutions")\nplt.show() '

# %% [markdown]
# ## Шаг 12. Объединение предсказаний в ансамбль

# %%
final_predictions = (
    0.4 * np.exp(models['catboost'].predict(test_final)) +
    0.2 * np.exp(models['br'].predict(test_final)) +
    0.2 * np.exp(models['gbr'].predict(test_final)) +
    0.15 * np.exp(models['ridge'].predict(test_final)) +
    0.05 * np.exp(models['omp'].predict(test_final))
)

final_predictions
# Out:
# array([123795.03740629, 156188.36817883, 180092.76543186, ...,
#        158693.5893597 , 116993.16360963, 220515.1958865 ])

# %% [markdown]
# ## Шаг 13. Создание таблицы предсказаний

# %% [markdown]
# Вглянем на образец таблицы:

# %%
sample_submission
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
submission = pd.concat([test_ids, pd.Series(final_predictions, name='SalePrice')], axis=1)
submission
# Out:
#         Id      SalePrice
# 0     1461  123795.037406
# 1     1462  156188.368179
# 2     1463  180092.765432
# 3     1464  192595.876925
# 4     1465  190488.661337
# ...    ...            ...
# 1454  2915   84900.016317
# 1455  2916   81276.213682
# 1456  2917  158693.589360
# 1457  2918  116993.163610
# 1458  2919  220515.195887
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('./submission.csv', index=False, header=True)

# %%
#000: base                      : 0.12381
#001: 0.2 * 5                   : 0.12507
#002: 0.2 * 5 + func            : 0.12457
#003: 0.5 cb + func             : 0.12213 best
#004: 0.4 cb + func             : 0.12256
#005: 0.45 cb + func            : 0.12245
